# %% [markdown]
# # Data Pipelines with Python

# %% [markdown]
# I am developing an automated data pipeline that can extract billing data from multiple sources and transform it into a structured format for efficient analysis and revenue reporting.

# %% [markdown]
# ## Pre-requisites

# %%
# Pre-requisite 1
# ---
# Importing pandas library for data manipulation
import pandas as pd
# Importing numpy library for scientific computations
import numpy as np

# %% [markdown]
# ## 1. Data Exploration

# %% [markdown]
# ### Load and Review the datasets

# %%
# Dataset url = https://bit.ly/416WE1X
# Dataset1 - subscriptions
subscription_df = pd.read_csv('https://raw.githubusercontent.com/wambasisamuel/DE_Week07_Monday/main/dataset1.csv')
subscription_df.head(5)
# Out:
#    customer_id date_of_purchase  total_amount_billed payment_status  \
# 0          101       04/01/2021                  100           paid
# 1          102       04/02/2021                  200           paid
# 2          103       04/02/2021                   50        overdue
# 3          104       04/03/2021                   75       disputed
# 4          105       04/04/2021                  125           paid
#
#   payment_method promo_code country_of_purchase
# 0    credit card     PROMO1                 USA
# 1  bank transfer     PROMO2                 USA
# 2    credit card        NaN                  UK
# 3       e-wallet     PROMO3                  UK
# 4    credit card     PROMO4                 USA

# %%
# Dataset2 - Payments
payment_df = pd.read_csv('https://raw.githubusercontent.com/wambasisamuel/DE_Week07_Monday/main/dataset2.csv')
payment_df.head(5)
# Out:
#    customer_id date_of_payment  amount_paid payment_method payment_status  \
# 0          101      04/01/2021          100    credit card           paid
# 1          102      04/03/2021          200  bank transfer           paid
# 2          103      04/03/2021           75    credit card           paid
# 3          104      04/04/2021           50       e-wallet        overdue
# 4          105      04/05/2021          125    credit card           paid
#
#    late_payment_fee country_of_payment
# 0                 0                USA
# 1                 0                USA
# 2                10                 UK
# 3                 0                 UK
# 4                 0                USA

# %%
# Dataset3 - Refunds
refund_df = pd.read_csv('https://raw.githubusercontent.com/wambasisamuel/DE_Week07_Monday/main/dataset3.csv')
refund_df.head(5)
# Out:
#    customer_id date_of_refund  refund_amount         reason_for_refund  \
# 0          101     04/03/2021            100  product not as described
# 1          102     04/06/2021            200         defective product
# 2          103     04/07/2021             75            change of mind
# 3          104     04/08/2021             50      product not received
# 4          105     04/09/2021             25  product not as described
#
#   country_of_refund
# 0               USA
# 1               USA
# 2                UK
# 3                UK
# 4               USA

# %% [markdown]
# ## 2. Data Preparation

# %% [markdown]
# ### Get column data types

# %%
# Function that prints the data types of columns for a given dataframe
def get_datatypes(df):
  df_name =[x for x in globals() if globals()[x] is df][0]
  print("\n" + df_name)
  print("=================")
  print(df.dtypes)

df_list = [subscription_df, payment_df, refund_df]

for df in df_list:
  get_datatypes(df)
# Out:
# subscription_df
# =================
# customer_id             int64
# date_of_purchase       object
# total_amount_billed     int64
# payment_status         object
# payment_method         object
# promo_code             object
# country_of_purchase    object
# dtype: object
#
# df
# =================
# customer_id            int64
# date_of_payment       object
# amount_paid            int64
# payment_method        object
# payment_status        object
# late_payment_fee       int64
# country_of_payment    object
# dtype: object
#
# refund_df
# =================
# customer_id           int64
# date_of_refund       object
# refund_amount         int64
# reason_for_refund    object
# country_of_refund    object
# dtype: object

# %% [markdown]
# ### Missing Values

# %%
# Function that prints the sum of missing values per columns for a given dataframe
def get_nulls(df):
  df_name =[x for x in globals() if globals()[x] is df][0]
  print("\n" + df_name)
  print("=================\n")
  print(df.isna().sum())

for df in df_list:
  get_nulls(df)
# Out:
# subscription_df
# =================
#
# customer_id            0
# date_of_purchase       0
# total_amount_billed    0
# payment_status         0
# payment_method         0
# promo_code             3
# country_of_purchase    0
# dtype: int64
#
# df
# =================
#
# customer_id           0
# date_of_payment       0
# amount_paid           0
# payment_method        0
# payment_status        0
# late_payment_fee      0
# country_of_payment    0
# dtype: int64
#
# refund_df
# =================
#
# customer_id          0
# date_of_refund       0
# refund_amount        0
# reason_for_refund    0
# country_of_refund    0
# dtype: int64

# %% [markdown]
# ### Duplicate data

# %%
# Function that prints number of duplicate records
def get_duplicates(df):
  df_name =[x for x in globals() if globals()[x] is df][0]
  print("\n" + df_name)
  print("=================\n")
  print(sum(df.duplicated()))

for df in df_list:
  get_duplicates(df)
# Out:
# subscription_df
# =================
#
# 0
#
# df
# =================
#
# 0
#
# refund_df
# =================
#
# 0

# %% [markdown]
# There are missing values for the Promo_code

# %% [markdown]
# ## 3. Data Transformation

# %% [markdown]
# ### Date Formatting

# %%
# Convert the date/time columns
subscription_df['date_of_purchase'] = pd.to_datetime(subscription_df['date_of_purchase'], infer_datetime_format=True)
payment_df['date_of_payment'] = pd.to_datetime(payment_df['date_of_payment'], infer_datetime_format=True)
refund_df['date_of_refund'] = pd.to_datetime(refund_df['date_of_refund'], infer_datetime_format=True)

# %% [markdown]
# ### Merging the Datasets

# %%
# Merge the datasets
subscription_payment_merge = pd.merge(left=subscription_df, right=payment_df, how='left', left_on=['customer_id','payment_status','payment_method'], right_on= ['customer_id','payment_status','payment_method'])
final_merged_df = pd.merge(left=subscription_payment_merge, right=refund_df, how='left', left_on=['customer_id'], right_on= ['customer_id'])

final_merged_df
# Out:
#     customer_id date_of_purchase  total_amount_billed payment_status  \
# 0           101       2021-01-04                  100           paid
# 1           102       2021-02-04                  200           paid
# 2           103       2021-02-04                   50        overdue
# 3           104       2021-03-04                   75       disputed
# 4           105       2021-04-04                  125           paid
# 5           106       2021-05-04                  150           paid
# 6           107       2021-06-04                   75        overdue
# 7           108       2021-06-04                  100        overdue
# 8           109       2021-07-04                   50           paid
# 9           110       2021-07-04                   25        overdue
# 10          111       2021-08-04                  175           paid
# 11          112       2021-08-04                  200           paid
# 12          113       2021-09-04                   50       disputed
# 13          114       2021-10-04                  100           paid
# 14          115       2021-10-04                   75        overdue
#
#    payment_method promo_code country_of_purchase date_of_payment_x  \
# 0     credit card     PROMO1                 USA        2021-01-04
# 1   bank transfer     PROMO2                 USA        2021-03-04
# 2     credit card        NaN                  UK               NaT
# 3        e-wallet     PROMO3                  UK               NaT
# 4     credit card     PROMO4                 USA        2021-05-04
# 5     credit card        NaN                  UK        2021-06-04
# 6        e-wallet     PROMO5                 USA        2021-07-04
# 7   bank transfer     PROMO6                 USA        2021-07-04
# 8   bank transfer        NaN                  UK        2021-08-04
# 9     credit card     PROMO7                 USA               NaT
# 10       e-wallet     PROMO8                  UK        2021-09-04
# 11  bank transfer     PROMO9                 USA        2021-10-04
# 12    credit card    PROMO10                 USA        2021-10-04
# 13    credit card    PROMO11                 USA        2021-11-04
# 14       e-wallet    PROMO12                  UK        2021-12-04
#
#     amount_paid  late_payment_fee country_of_payment date_of_refund  \
# 0         100.0               0.0                USA     2021-03-04
# 1         200.0               0.0                USA     2021-06-04
# 2           NaN               NaN                NaN     2021-07-04
# 3           NaN               NaN                NaN     2021-08-04
# 4         125.0               0.0                USA     2021-09-04
# 5         150.0               0.0                 UK     2021-11-04
# 6          75.0              20.0                USA     2021-12-04
# 7         100.0              30.0                USA     2021-04-13
# 8          50.0               0.0                 UK     2021-04-13
# 9           NaN               NaN                NaN     2021-04-14
# 10        175.0               0.0                 UK     2021-04-15
# 11        200.0               0.0                USA     2021-04-16
# 12         50.0               0.0                USA     2021-04-16
# 13        100.0               0.0                USA     2021-04-17
# 14         75.0              15.0                 UK     2021-04-18
#
#     refund_amount         reason_for_refund country_of_refund  \
# 0             100  product not as described               USA
# 1             200         defective product               USA
# 2              75            change of mind                UK
# 3              50      product not received                UK
# 4              25  product not as described               USA
# 5             125         defective product                UK
# 6             150            change of mind               USA
# 7              75  product not as described               USA
# 8             100         defective product                UK
# 9              50      product not received               USA
# 10            175         defective product                UK
# 11            200            change of mind               USA
# 12             50  product not as described               USA
# 13            100         defective product               USA
# 14             75      product not received                UK
#
#    date_of_payment_y
# 0         2021-03-04
# 1         2021-06-04
# 2         2021-07-04
# 3         2021-08-04
# 4         2021-09-04
# 5         2021-11-04
# 6         2021-12-04
# 7         2021-04-13
# 8         2021-04-13
# 9         2021-04-14
# 10        2021-04-15
# 11        2021-04-16
# 12        2021-04-16
# 13        2021-04-17
# 14        2021-04-18

# %% [markdown]
# ### Unpaid Bills

# %%
final_merged_df = final_merged_df[final_merged_df['payment_status'] != 'paid']
final_merged_df
# Out:
#     customer_id date_of_purchase  total_amount_billed payment_status  \
# 2           103       2021-02-04                   50        overdue
# 3           104       2021-03-04                   75       disputed
# 6           107       2021-06-04                   75        overdue
# 7           108       2021-06-04                  100        overdue
# 9           110       2021-07-04                   25        overdue
# 12          113       2021-09-04                   50       disputed
# 14          115       2021-10-04                   75        overdue
#
#    payment_method promo_code country_of_purchase date_of_payment_x  \
# 2     credit card        NaN                  UK               NaT
# 3        e-wallet     PROMO3                  UK               NaT
# 6        e-wallet     PROMO5                 USA        2021-07-04
# 7   bank transfer     PROMO6                 USA        2021-07-04
# 9     credit card     PROMO7                 USA               NaT
# 12    credit card    PROMO10                 USA        2021-10-04
# 14       e-wallet    PROMO12                  UK        2021-12-04
#
#     amount_paid  late_payment_fee country_of_payment date_of_refund  \
# 2           NaN               NaN                NaN     2021-07-04
# 3           NaN               NaN                NaN     2021-08-04
# 6          75.0              20.0                USA     2021-12-04
# 7         100.0              30.0                USA     2021-04-13
# 9           NaN               NaN                NaN     2021-04-14
# 12         50.0               0.0                USA     2021-04-16
# 14         75.0              15.0                 UK     2021-04-18
#
#     refund_amount         reason_for_refund country_of_refund  \
# 2              75            change of mind                UK
# 3              50      product not received                UK
# 6             150            change of mind               USA
# 7              75  product not as described               USA
# 9              50      product not received               USA
# 12             50  product not as described               USA
# 14             75      product not received                UK
#
#    date_of_payment_y
# 2         2021-07-04
# 3         2021-08-04
# 6         2021-12-04
# 7         2021-04-13
# 9         2021-04-14
# 12        2021-04-16
# 14        2021-04-18

# %% [markdown]
# ## 4. Data Loading

# %% [markdown]
# ### Output to csv file

# %%
final_merged_df.to_csv('unpaid_bills.csv', header=True, index=False)

# %% [markdown]
# ## 5. Automation

# %% [markdown]
# I will configure a cronjob to run the notebook everydat at 4am:
#
# 0 4 * * * /path/to/notebook.ipynb
